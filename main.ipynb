# %%
#!pip install beautifulsoup4
#!pip install httpx
#!pip install fastcore

# %%
from bs4 import BeautifulSoup
import httpx
import os
from fastcore.parallel import parallel
import time

def fetch_random_wiki_page():
    """Fetches a random Wikipedia page and returns its title and content."""
    url = 'https://en.wikipedia.org/wiki/Special:Random'
    response = httpx.get(url, follow_redirects=True)
    soup = BeautifulSoup(response.text, 'html.parser')

    title = soup.select_one('#firstHeading').text
    paragraphs = soup.select('.mw-parser-output > p, .mw-parser-output > ul li, .mw-parser-output table.infobox td, .mw-parser-output > h2, .mw-parser-output > h3')
    content = '\n\n'.join(p.text.strip() for p in paragraphs if p.text.strip())

    return title, content

def save_article(title, content, article_index):
    """Saves the article content to a file with a sanitized title."""
    safe_title = ''.join(c for c in title if c.isalnum() or c in (' ', '-', '_')).rstrip()
    os.makedirs('wiki_articles_new', exist_ok=True)
    filename = f'wiki_articles_new/article_{article_index}_{safe_title}.txt'

    with open(filename, 'w', encoding='utf-8') as f:
        f.write(f"Title: {title}\n\n")
        f.write(content)

    return filename

def get_article_with_retries(article_index, min_length=2000, max_retries=15):
    """Fetches and saves a random Wikipedia article, retrying if it's too short."""
    for attempt in range(max_retries):
        try:
            title, content = fetch_random_wiki_page()

            if len(content) >= min_length:
                print(f"Saved article {article_index}: {title} ({len(content)} chars)")
                return save_article(title, content, article_index)

            print(f"Attempt {attempt + 1} for article {article_index}: Too short ({len(content)} chars)")
        except Exception as e:
            print(f"Error on attempt {attempt + 1} for article {article_index}: {e}")

        time.sleep(1)


    print(f"Failed to fetch suitable article for position {article_index} after {max_retries} attempts")
    return None

def process_article(i, min_length):
    """Processes a single article fetch operation."""
    return get_article_with_retries(i + 1, min_length)

def fetch_multiple_articles(num_articles=1, min_length=1000):
    """Fetches multiple random Wikipedia articles in parallel."""
    print(f"Fetching {num_articles} articles with a minimum length of {min_length} characters...")
    articles = parallel(process_article, range(num_articles), n_workers=20, min_length=min_length)
    successful_articles = [article for article in articles if article]

    print(f"\nSuccessfully saved {len(successful_articles)}/{num_articles} articles")
    return successful_articles

saved_files = fetch_multiple_articles(num_articles=150, min_length=1500)
# Out:
# Fetching 150 articles with a minimum length of 1500 characters...
# Attempt 1 for article 18: Too short (516 chars)
# Attempt 1 for article 9: Too short (678 chars)
# Attempt 1 for article 13: Too short (1497 chars)
# Attempt 1 for article 1: Too short (276 chars)
# Attempt 1 for article 11: Too short (1076 chars)
# Attempt 1 for article 16: Too short (389 chars)
# Attempt 1 for article 7: Too short (763 chars)
# Saved article 4: B.C. Ziegler (5922 chars)
# Attempt 1 for article 20: Too short (89 chars)
# Attempt 1 for article 15: Too short (1077 chars)
# Saved article 19: Gareth Jones (journalist) (1754 chars)
# Saved article 10: Saco–Pettee Machine Shops (2553 chars)
# Attempt 1 for article 5: Too short (436 chars)
# Attempt 1 for article 17: Too short (748 chars)
# Attempt 1 for article 14: Too short (626 chars)
# Attempt 1 for article 12: Too short (649 chars)
# Attempt 1 for article 3: Too short (883 chars)
# Attempt 10 for article 93: Too short (516 chars)
# Attempt 3 for article 126: Too short (355 chars)
# Attempt 7 for article 109: Too short (353 chars)
# Saved article 131: Herring Hotel (Belle Plaine, Iowa) (2097 chars)
# Attempt 2 for article 130: Too short (317 chars)
# Attempt 9 for article 100: Too short (618 chars)
# Attempt 6 for article 113: Too short (587 chars)
# Attempt 6 for article 114: Too short (721 chars)
# Attempt 5 for article 115: Too short (842 chars)
# Attempt 4 for article 123: Too short (730 chars)
# Attempt 1 for article 133: Too short (849 chars)
# Attempt 12 for article 87: Too short (1056 chars)
# Attempt 5 for article 124: Too short (529 chars)
# Attempt 5 for article 117: Too short (922 chars)
# Attempt 2 for article 129: Too short (661 chars)
# Attempt 3 for article 128: Too short (592 chars)
# Attempt 1 for article 132: Too short (889 chars)
# Attempt 14 for article 85: Too short (876 chars)
# Attempt 11 for article 93: Too short (508 chars)
# Attempt 4 for article 126: Too short (496 chars)
# Attempt 7 for article 113: Too short (265 chars)
# Saved article 109: Lower Marsh (1999 chars)
# Attempt 5 for article 120: Too short (305 chars)
# Saved article 100: 2002 Espirito Santo Trophy (1912 chars)
# Attempt 3 for article 130: Too short (792 chars)
# Attempt 2 for article 133: Too short (419 chars)
# Attempt 7 for article 114: Too short (535 chars)
# Saved article 123: Seiji Ogawa (1539 chars)
# Attempt 6 for article 115: Too short (246 chars)
# Attempt 11 for article 92: Too short (496 chars)
# Attempt 6 for article 117: Too short (427 chars)
# Attempt 2 for article 132: Too short (1204 chars)
# Attempt 1 for article 135: Too short (434 chars)
# Attempt 1 for article 134: Too short (869 chars)
# Attempt 4 for article 128: Too short (317 chars)
# Attempt 5 for article 108: Too short (951 chars)
# Attempt 13 for article 87: Too short (970 chars)
# Saved article 129: Wilmington High School (Ohio) (1727 chars)
# Attempt 6 for article 120: Too short (942 chars)
# Saved article 124: Navajo language (2481 chars)
# Saved article 126: Fascination! (2840 chars)
# Attempt 3 for article 133: Too short (347 chars)
# Attempt 8 for article 113: Too short (789 chars)
# Attempt 12 for article 93: Too short (1335 chars)
# Attempt 8 for article 114: Too short (1235 chars)
# Attempt 1 for article 136: Too short (716 chars)
# Attempt 15 for article 85: Too short (380 chars)
# Attempt 4 for article 130: Too short (312 chars)
# Attempt 12 for article 92: Too short (1042 chars)
# Attempt 2 for article 134: Too short (544 chars)
# Attempt 7 for article 115: Too short (1004 chars)
# Attempt 7 for article 117: Too short (283 chars)
# Attempt 1 for article 137: Too short (713 chars)
# Failed to fetch suitable article for position 85 after 15 attempts
# Attempt 14 for article 87: Too short (0 chars)
# Attempt 1 for article 139: Too short (570 chars)
# Attempt 1 for article 138: Too short (512 chars)
# Saved article 120: Trialeti (town) (1567 chars)
# Attempt 6 for article 108: Too short (981 chars)
# Attempt 5 for article 128: Too short (574 chars)
# Attempt 3 for article 132: Too short (957 chars)
# Attempt 2 for article 135: Too short (664 chars)
# Attempt 4 for article 133: Too short (679 chars)
# Saved article 93: Ochlodes (2032 chars)
# Attempt 1 for article 141: Too short (486 chars)
# Attempt 9 for article 138: Too short (1011 chars)
# Attempt 7 for article 147: Too short (799 chars)
# Attempt 9 for article 142: Too short (381 chars)
# Attempt 9 for article 136: Too short (889 chars)
# Attempt 9 for article 135: Too short (182 chars)
# Attempt 9 for article 137: Too short (257 chars)
# Saved article 115: Pixmania (3459 chars)
# Attempt 10 for article 139: Too short (943 chars)
# Attempt 6 for article 150: Too short (272 chars)
# Attempt 7 for article 143: Too short (320 chars)
# Attempt 10 for article 136: Too short (1101 chars)
# Attempt 8 for article 147: Too short (284 chars)
# Attempt 10 for article 135: Too short (257 chars)
# Attempt 10 for article 142: Too short (628 chars)
# Saved article 143: SBA Communications (1677 chars)
# Attempt 7 for article 150: Too short (991 chars)
# Attempt 11 for article 139: Too short (1158 chars)
# Attempt 10 for article 138: Too short (663 chars)
# Attempt 10 for article 137: Too short (503 chars)
# Saved article 142: Chiaramonte (1660 chars)
# Attempt 11 for article 135: Too short (369 chars)
# Attempt 11 for article 136: Too short (588 chars)
# Attempt 9 for article 147: Too short (1143 chars)
# Attempt 8 for article 150: Too short (600 chars)
# Attempt 11 for article 138: Too short (469 chars)
# Attempt 12 for article 139: Too short (786 chars)
# Attempt 12 for article 136: Too short (1216 chars)
# Saved article 135: Sofia Theological Seminary (1967 chars)
# Attempt 11 for article 137: Too short (1163 chars)
# Attempt 9 for article 150: Too short (579 chars)
# Attempt 12 for article 138: Too short (861 chars)
# Attempt 13 for article 139: Too short (1499 chars)
# Attempt 13 for article 136: Too short (836 chars)
# Attempt 10 for article 147: Too short (870 chars)
# Attempt 12 for article 137: Too short (1417 chars)
# Attempt 13 for article 138: Too short (786 chars)
# Attempt 10 for article 150: Too short (303 chars)
# Attempt 14 for article 136: Too short (855 chars)
# Attempt 14 for article 139: Too short (242 chars)
# Attempt 11 for article 147: Too short (1448 chars)
# Saved article 137: Konark Dance Festival (2209 chars)
# Attempt 14 for article 138: Too short (1100 chars)
# Attempt 11 for article 150: Too short (467 chars)
# Attempt 15 for article 139: Too short (643 chars)
# Attempt 12 for article 147: Too short (936 chars)
# Attempt 15 for article 136: Too short (322 chars)
# Failed to fetch suitable article for position 139 after 15 attempts
# Failed to fetch suitable article for position 136 after 15 attempts
# Attempt 12 for article 150: Too short (434 chars)
# Attempt 15 for article 138: Too short (1029 chars)
# Attempt 13 for article 147: Too short (1025 chars)
# Failed to fetch suitable article for position 138 after 15 attempts
# Attempt 13 for article 150: Too short (400 chars)
# Attempt 14 for article 150: Too short (359 chars)
# Attempt 14 for article 147: Too short (701 chars)
# Attempt 15 for article 147: Too short (1214 chars)
# Failed to fetch suitable article for position 147 after 15 attempts
# Attempt 15 for article 150: Too short (455 chars)
# Failed to fetch suitable article for position 150 after 15 attempts
#
# Successfully saved 134/150 articles

# %%
#2
import re

def clean_text(text):
    cleaned_text = re.sub(r'\[\d+\]', '', text)
    return cleaned_text

def clean_existing_articles(directory='./wiki_articles_first'):
    files = os.listdir(directory)
    
    for file in files:
        file_path = os.path.join(directory, file)
        
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()

        cleaned_content = clean_text(content)
        
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(cleaned_content)
clean_existing_articles()

# %%
import os
import random
import csv

random_words = ["Mango", "Apple", "Guava", "Strawberry", "Avocado", "Pineapple", "Papaya", "Orange"]

def add_single_random_word_to_articles(directory='wiki_articles_first', output_csv='fruit_log.csv'):
    log_data = []
    
    files = os.listdir(directory)
    
    for file in files:
        file_path = os.path.join(directory, file)
        
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
        
        paragraphs = content.split('\n\n')
        
        if len(paragraphs) > 1:
            para_idx = random.randint(1, len(paragraphs) - 1)
            words = paragraphs[para_idx].split()
            if words:
                insert_pos = random.randint(0, len(words))
                random_word = random.choice(random_words)
                words.insert(insert_pos, f"[{random_word}]")
                paragraphs[para_idx] = ' '.join(words)
        
            modified_content = '\n\n'.join(paragraphs)
            
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(modified_content)
            
            parts = file.split('_')
            if len(parts) > 2:
                article_number = parts[1]
                article_title = ' '.join(parts[2:]).replace('.txt', '')
            else:
                article_number = parts[0].replace('.txt', '')
                article_title = "Unknown"
            
            log_data.append({
                "Title": article_title,
                "Fruit_added": random_word
            })
            
            #print(f"Added '{random_word}' to {file}")
    
    with open(output_csv, 'w', newline='', encoding='utf-8') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=["Title", "Fruit_added"])
        writer.writeheader()
        writer.writerows(log_data)
    
    print(f"Log has been saved to {output_csv}")

add_single_random_word_to_articles()
# Out:
# Log has been saved to fruit_log.csv

# %%
#5
import re

def remove_brackets_keep_words(directory='./wiki_articles_first'):
    files = os.listdir(directory)
    
    for file in files:
        file_path = os.path.join(directory, file)
        
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read()
        
        cleaned_content = re.sub(r'\[(.*?)\]', r'\1', content)
        
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(cleaned_content)
            
remove_brackets_keep_words()

# %%
import os
import json

input_folder = "wiki_articles_first"
output_file = "./json/wikipedia_first.json"

documents = []

for file_name in os.listdir(input_folder):
    if file_name.endswith(".txt"):
        file_path = os.path.join(input_folder, file_name)
        
        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read().strip()
        
        documents.append({"src": content})

with open(output_file, "w", encoding="utf-8") as json_file:
    json.dump(documents, json_file, indent=4, ensure_ascii=False)

print(f"JSON file successfully created at {output_file}")
# Out:
# JSON file successfully created at ./json/wikipedia_first.json

# %%
import json
import csv

INPUT_JSON = "/home/staru/Desktop/main/output/wikipedia_first.json"   
OUTPUT_CSV = "results/output.csv"  

def main():
    try:
        with open(INPUT_JSON, 'r', encoding='utf-8') as json_file:
            data = json.load(json_file)
        
        results = []
        for entry in data:
            src = entry.get("src", "")
            title = "No Title Found"
            if "Title: " in src:
                title = src.split("Title: ")[1].split('\n')[0]
            hidden_fruits = entry.get("hidden_fruits", [])
            results.append({"title": title, "hidden_fruits": hidden_fruits})
        
        with open(OUTPUT_CSV, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(["Title", "Hidden_Fruits"])
            for item in results:
                title = item['title']
                fruits_str = ",".join(item['hidden_fruits'])
                writer.writerow([title, fruits_str])
        
        print(f"Successfully generated CSV: {OUTPUT_CSV}")
    
    except FileNotFoundError:
        print(f"Error: File '{INPUT_JSON}' not found.")
    except json.JSONDecodeError:
        print(f"Error: Invalid JSON format in '{INPUT_JSON}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Successfully generated CSV: results/output.csv
